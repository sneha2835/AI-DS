# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import string
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag, ne_chunk

# %% [markdown]
# **Download NLTK Resources**

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %% [markdown]
# 1. Tokenization
# 2. Stemming
# 3. Lemmatization
# 4. POS Tag
# 5. NER

# %% [markdown]
# **Load spaCy Model**

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# **Initialize Tools**

# %%
lemmatizer = WordNetLemmatizer()
stemmer= PorterStemmer()
stop_words = set(stopwords.words('english'))

# %% [markdown]
# **Load Data**

# %%
df = pd.read_csv("/content/SMSSpamCollection.txt", sep="\t", names=["label", "message"])

# %%
df
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# **Step 1: Lowercase**

# %%
df['lower'] = df['message'].str.lower()

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
# [5572 rows x 3 columns]

# %% [markdown]
# **Step 2: Remove Punctuation**

# %%
def remove_punct(text):
    return ''.join([char for char in text if char not in string.punctuation])

df['no_punct'] = df['lower'].apply(remove_punct)

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
# [5572 rows x 4 columns]

# %% [markdown]
# **Step 3: Tokenization (NLTK)**

# %%
df['tokens'] = df['no_punct'].apply(word_tokenize)

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
# [5572 rows x 5 columns]

# %% [markdown]
# **Step 4: Remove Stopwords**

# %%
df['tokens_no_stopwords'] = df['tokens'].apply(lambda tokens: [t for t in tokens if t not in stop_words])

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
# [5572 rows x 6 columns]

# %% [markdown]
# **Step 5: NLTK Lemmatization**

# %%
df['nltk_lemmas'] = df['tokens_no_stopwords'].apply(lambda tokens: [lemmatizer.lemmatize(t) for t in tokens])

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                             nltk_lemmas
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                    [pity, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
# [5572 rows x 7 columns]

# %% [markdown]
# **Step 6: NLTK Stemming**

# %%
df['nltk_stems'] = df['tokens_no_stopwords'].apply(lambda tokens: [stemmer.stem(t) for t in tokens])

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                             nltk_lemmas  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                    [pity, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                              nltk_stems
# 0     [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                          [ok, lar, joke, wif, u, oni]
# 2     [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         [u, dun, say, earli, hor, u, c, alreadi, say]
# 4     [nah, dont, think, goe, usf, live, around, tho...
# ...                                                 ...
# 5567  [2nd, time, tri, 2, contact, u, u, £750, pound...
# 5568                     [ü, b, go, esplanad, fr, home]
# 5569                       [piti, mood, soani, suggest]
# 5570  [guy, bitch, act, like, id, interest, buy, som...
# 5571                                 [rofl, true, name]
#
# [5572 rows x 8 columns]

# %% [markdown]
# **Step 7: NLTK POS Tagging**

# %%
df['nltk_pos'] = df['tokens_no_stopwords'].apply(pos_tag)

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                             nltk_lemmas  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                    [pity, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                              nltk_stems  \
# 0     [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                          [ok, lar, joke, wif, u, oni]
# 2     [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         [u, dun, say, earli, hor, u, c, alreadi, say]
# 4     [nah, dont, think, goe, usf, live, around, tho...
# ...                                                 ...
# 5567  [2nd, time, tri, 2, contact, u, u, £750, pound...
# 5568                     [ü, b, go, esplanad, fr, home]
# 5569                       [piti, mood, soani, suggest]
# 5570  [guy, bitch, act, like, id, interest, buy, som...
# 5571                                 [rofl, true, name]
#
#                                                nltk_pos
# 0     [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1     [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2     [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3     [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4     [(nah, JJ), (dont, NN), (think, NN), (goes, VB...
# ...                                                 ...
# 5567  [(2nd, CD), (time, NN), (tried, VBD), (2, CD),...
# 5568  [(ü, NN), (b, NN), (going, VBG), (esplanade, J...
# 5569  [(pity, NN), (mood, NN), (soany, JJ), (suggest...
# 5570  [(guy, NN), (bitching, VBG), (acted, VBN), (li...
# 5571               [(rofl, NN), (true, JJ), (name, NN)]
#
# [5572 rows x 9 columns]

# %% [markdown]
# **Step 8: NLTK Named Entity Recognition**

# %%
df['nltk_ner'] = df['nltk_pos'].apply(ne_chunk)

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                             nltk_lemmas  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                    [pity, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                              nltk_stems  \
# 0     [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                          [ok, lar, joke, wif, u, oni]
# 2     [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         [u, dun, say, earli, hor, u, c, alreadi, say]
# 4     [nah, dont, think, goe, usf, live, around, tho...
# ...                                                 ...
# 5567  [2nd, time, tri, 2, contact, u, u, £750, pound...
# 5568                     [ü, b, go, esplanad, fr, home]
# 5569                       [piti, mood, soani, suggest]
# 5570  [guy, bitch, act, like, id, interest, buy, som...
# 5571                                 [rofl, true, name]
#
#                                                nltk_pos  \
# 0     [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1     [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2     [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3     [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4     [(nah, JJ), (dont, NN), (think, NN), (goes, VB...
# ...                                                 ...
# 5567  [(2nd, CD), (time, NN), (tried, VBD), (2, CD),...
# 5568  [(ü, NN), (b, NN), (going, VBG), (esplanade, J...
# 5569  [(pity, NN), (mood, NN), (soany, JJ), (suggest...
# 5570  [(guy, NN), (bitching, VBG), (acted, VBN), (li...
# 5571               [(rofl, NN), (true, JJ), (name, NN)]
#
#                                                nltk_ner
# 0     [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1     [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2     [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3     [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4     [(nah, JJ), (dont, NN), (think, NN), (goes, VB...
# ...                                                 ...
# 5567  [(2nd, CD), (time, NN), (tried, VBD), (2, CD),...
# 5568  [(ü, NN), (b, NN), (going, VBG), (esplanade, J...
# 5569  [(pity, NN), (mood, NN), (soany, JJ), (suggest...
# 5570  [(guy, NN), (bitching, VBG), (acted, VBN), (li...
# 5571               [(rofl, NN), (true, JJ), (name, NN)]
#
# [5572 rows x 10 columns]

# %% [markdown]
# **Step 9: spaCy NLP Pipeline**

# %%
def spacy_pipeline(text):
    doc = nlp(text)
    return {
        'spacy_tokens': [token.text for token in doc],
        'spacy_stems': [stemmer.stem(token.text) for token in doc],
        'spacy_lemmas': [token.lemma_ for token in doc],
        'spacy_pos': [(token.text, token.pos_) for token in doc],
        'spacy_ner': [(ent.text, ent.label_) for ent in doc.ents]
    }

# %% [markdown]
# **Apply spaCy Pipeline**

# %%
spacy_results = df['message'].apply(spacy_pipeline)

# %% [markdown]
# **Step 10: Extract spaCy Results into Columns**

# %%
df['spacy_tokens'] = spacy_results.apply(lambda x: x['spacy_tokens'])
df['spacy_stems'] = spacy_results.apply(lambda x: x['spacy_stems'])
df['spacy_lemmas'] = spacy_results.apply(lambda x: x['spacy_lemmas'])
df['spacy_pos'] = spacy_results.apply(lambda x: x['spacy_pos'])
df['spacy_ner'] = spacy_results.apply(lambda x: x['spacy_ner'])

# %%
df
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, f...
# 3     [u, dun, say, so, early, hor, u, c, already, t...
# 4     [nah, i, dont, think, he, goes, to, usf, he, l...
# ...                                                 ...
# 5567  [this, is, the, 2nd, time, we, have, tried, 2,...
# 5568       [will, ü, b, going, to, esplanade, fr, home]
# 5569  [pity, was, in, mood, for, that, soany, other,...
# 5570  [the, guy, did, some, bitching, but, i, acted,...
# 5571                   [rofl, its, true, to, its, name]
#
#                                     tokens_no_stopwords  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, goes, usf, lives, around, t...
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                   [pity, mood, soany, suggestions]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                             nltk_lemmas  \
# 0     [go, jurong, point, crazy, available, bugis, n...
# 1                        [ok, lar, joking, wif, u, oni]
# 2     [free, entry, 2, wkly, comp, win, fa, cup, fin...
# 3         [u, dun, say, early, hor, u, c, already, say]
# 4     [nah, dont, think, go, usf, life, around, though]
# ...                                                 ...
# 5567  [2nd, time, tried, 2, contact, u, u, £750, pou...
# 5568                 [ü, b, going, esplanade, fr, home]
# 5569                    [pity, mood, soany, suggestion]
# 5570  [guy, bitching, acted, like, id, interested, b...
# 5571                                 [rofl, true, name]
#
#                                              nltk_stems  \
# 0     [go, jurong, point, crazi, avail, bugi, n, gre...
# 1                          [ok, lar, joke, wif, u, oni]
# 2     [free, entri, 2, wkli, comp, win, fa, cup, fin...
# 3         [u, dun, say, earli, hor, u, c, alreadi, say]
# 4     [nah, dont, think, goe, usf, live, around, tho...
# ...                                                 ...
# 5567  [2nd, time, tri, 2, contact, u, u, £750, pound...
# 5568                     [ü, b, go, esplanad, fr, home]
# 5569                       [piti, mood, soani, suggest]
# 5570  [guy, bitch, act, like, id, interest, buy, som...
# 5571                                 [rofl, true, name]
#
#                                                nltk_pos  \
# 0     [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1     [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2     [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3     [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4     [(nah, JJ), (dont, NN), (think, NN), (goes, VB...
# ...                                                 ...
# 5567  [(2nd, CD), (time, NN), (tried, VBD), (2, CD),...
# 5568  [(ü, NN), (b, NN), (going, VBG), (esplanade, J...
# 5569  [(pity, NN), (mood, NN), (soany, JJ), (suggest...
# 5570  [(guy, NN), (bitching, VBG), (acted, VBN), (li...
# 5571               [(rofl, NN), (true, JJ), (name, NN)]
#
#                                                nltk_ner  \
# 0     [(go, VB), (jurong, JJ), (point, NN), (crazy, ...
# 1     [(ok, JJ), (lar, JJ), (joking, NN), (wif, NN),...
# 2     [(free, JJ), (entry, NN), (2, CD), (wkly, JJ),...
# 3     [(u, JJ), (dun, NNS), (say, VBP), (early, JJ),...
# 4     [(nah, JJ), (dont, NN), (think, NN), (goes, VB...
# ...                                                 ...
# 5567  [(2nd, CD), (time, NN), (tried, VBD), (2, CD),...
# 5568  [(ü, NN), (b, NN), (going, VBG), (esplanade, J...
# 5569  [(pity, NN), (mood, NN), (soany, JJ), (suggest...
# 5570  [(guy, NN), (bitching, VBG), (acted, VBN), (li...
# 5571               [(rofl, NN), (true, JJ), (name, NN)]
#
#                                            spacy_tokens  \
# 0     [Go, until, jurong, point, ,, crazy, .., Avail...
# 1              [Ok, lar, ..., Joking, wif, u, oni, ...]
# 2     [Free, entry, in, 2, a, wkly, comp, to, win, F...
# 3     [U, dun, say, so, early, hor, ..., U, c, alrea...
# 4     [Nah, I, do, n't, think, he, goes, to, usf, ,,...
# ...                                                 ...
# 5567  [This, is, the, 2nd, time, we, have, tried, 2,...
# 5568    [Will, ü, b, going, to, esplanade, fr, home, ?]
# 5569  [Pity, ,, *, was, in, mood, for, that, ., So, ...
# 5570  [The, guy, did, some, bitching, but, I, acted,...
# 5571                [Rofl, ., Its, true, to, its, name]
#
#                                             spacy_stems  \
# 0     [go, until, jurong, point, ,, crazi, .., avail...
# 1                [ok, lar, ..., joke, wif, u, oni, ...]
# 2     [free, entri, in, 2, a, wkli, comp, to, win, f...
# 3     [u, dun, say, so, earli, hor, ..., u, c, alrea...
# 4     [nah, i, do, n't, think, he, goe, to, usf, ,, ...
# ...                                                 ...
# 5567  [thi, is, the, 2nd, time, we, have, tri, 2, co...
# 5568        [will, ü, b, go, to, esplanad, fr, home, ?]
# 5569  [piti, ,, *, wa, in, mood, for, that, ., so, ....
# 5570  [the, guy, did, some, bitch, but, i, act, like...
# 5571                  [rofl, ., it, true, to, it, name]
#
#                                            spacy_lemmas  \
# 0     [go, until, jurong, point, ,, crazy, .., avail...
# 1                [ok, lar, ..., joke, wif, u, oni, ...]
# 2     [free, entry, in, 2, a, wkly, comp, to, win, F...
# 3     [u, dun, say, so, early, hor, ..., u, c, alrea...
# 4     [Nah, I, do, not, think, he, go, to, usf, ,, h...
# ...                                                 ...
# 5567  [this, be, the, 2nd, time, we, have, try, 2, c...
# 5568       [will, ü, b, go, to, esplanade, fr, home, ?]
# 5569  [pity, ,, *, be, in, mood, for, that, ., so, ....
# 5570  [the, guy, do, some, bitching, but, I, act, li...
# 5571                [rofl, ., its, true, to, its, name]
#
#                                               spacy_pos  \
# 0     [(Go, VERB), (until, ADP), (jurong, PROPN), (p...
# 1     [(Ok, INTJ), (lar, ADJ), (..., PUNCT), (Joking...
# 2     [(Free, ADJ), (entry, NOUN), (in, ADP), (2, NU...
# 3     [(U, ADJ), (dun, NOUN), (say, VERB), (so, ADV)...
# 4     [(Nah, PROPN), (I, PRON), (do, AUX), (n't, PAR...
# ...                                                 ...
# 5567  [(This, PRON), (is, AUX), (the, DET), (2nd, AD...
# 5568  [(Will, AUX), (ü, PROPN), (b, AUX), (going, VE...
# 5569  [(Pity, INTJ), (,, PUNCT), (*, PUNCT), (was, A...
# 5570  [(The, DET), (guy, NOUN), (did, VERB), (some, ...
# 5571  [(Rofl, ADP), (., PUNCT), (Its, PRON), (true, ...
#
#                                               spacy_ner
# 0                                      [(Cine, PERSON)]
# 1                                                    []
# 2     [(2, CARDINAL), (FA Cup, EVENT), (21st May 200...
# 3                                    [(U dun, PRODUCT)]
# 4                                                    []
# ...                                                 ...
# 5567  [(2nd, ORDINAL), (2, CARDINAL), (2, CARDINAL),...
# 5568                                                 []
# 5569                                                 []
# 5570                                [(next week, DATE)]
# 5571                                                 []
#
# [5572 rows x 15 columns]

# %%
df.to_csv("/content/processed_sms_nlp.csv", index=False)

# %%
df1=pd.read_csv('/content/processed_sms_nlp.csv')

# %%
df1
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                                   lower  \
# 0     go until jurong point, crazy.. available only ...
# 1                         ok lar... joking wif u oni...
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3     u dun say so early hor... u c already then say...
# 4     nah i don't think he goes to usf, he lives aro...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568               will ü b going to esplanade fr home?
# 5569  pity, * was in mood for that. so...any other s...
# 5570  the guy did some bitching but i acted like i'd...
# 5571                         rofl. its true to its name
#
#                                                no_punct  \
# 0     go until jurong point crazy available only in ...
# 1                               ok lar joking wif u oni
# 2     free entry in 2 a wkly comp to win fa cup fina...
# 3           u dun say so early hor u c already then say
# 4     nah i dont think he goes to usf he lives aroun...
# ...                                                 ...
# 5567  this is the 2nd time we have tried 2 contact u...
# 5568                will ü b going to esplanade fr home
# 5569  pity  was in mood for that soany other suggest...
# 5570  the guy did some bitching but i acted like id ...
# 5571                          rofl its true to its name
#
#                                                  tokens  \
# 0     ['go', 'until', 'jurong', 'point', 'crazy', 'a...
# 1            ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# 2     ['free', 'entry', 'in', '2', 'a', 'wkly', 'com...
# 3     ['u', 'dun', 'say', 'so', 'early', 'hor', 'u',...
# 4     ['nah', 'i', 'dont', 'think', 'he', 'goes', 't...
# ...                                                 ...
# 5567  ['this', 'is', 'the', '2nd', 'time', 'we', 'ha...
# 5568  ['will', 'ü', 'b', 'going', 'to', 'esplanade',...
# 5569  ['pity', 'was', 'in', 'mood', 'for', 'that', '...
# 5570  ['the', 'guy', 'did', 'some', 'bitching', 'but...
# 5571       ['rofl', 'its', 'true', 'to', 'its', 'name']
#
#                                     tokens_no_stopwords  \
# 0     ['go', 'jurong', 'point', 'crazy', 'available'...
# 1            ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# 2     ['free', 'entry', '2', 'wkly', 'comp', 'win', ...
# 3     ['u', 'dun', 'say', 'early', 'hor', 'u', 'c', ...
# 4     ['nah', 'dont', 'think', 'goes', 'usf', 'lives...
# ...                                                 ...
# 5567  ['2nd', 'time', 'tried', '2', 'contact', 'u', ...
# 5568     ['ü', 'b', 'going', 'esplanade', 'fr', 'home']
# 5569           ['pity', 'mood', 'soany', 'suggestions']
# 5570  ['guy', 'bitching', 'acted', 'like', 'id', 'in...
# 5571                           ['rofl', 'true', 'name']
#
#                                             nltk_lemmas  \
# 0     ['go', 'jurong', 'point', 'crazy', 'available'...
# 1            ['ok', 'lar', 'joking', 'wif', 'u', 'oni']
# 2     ['free', 'entry', '2', 'wkly', 'comp', 'win', ...
# 3     ['u', 'dun', 'say', 'early', 'hor', 'u', 'c', ...
# 4     ['nah', 'dont', 'think', 'go', 'usf', 'life', ...
# ...                                                 ...
# 5567  ['2nd', 'time', 'tried', '2', 'contact', 'u', ...
# 5568     ['ü', 'b', 'going', 'esplanade', 'fr', 'home']
# 5569            ['pity', 'mood', 'soany', 'suggestion']
# 5570  ['guy', 'bitching', 'acted', 'like', 'id', 'in...
# 5571                           ['rofl', 'true', 'name']
#
#                                              nltk_stems  \
# 0     ['go', 'jurong', 'point', 'crazi', 'avail', 'b...
# 1              ['ok', 'lar', 'joke', 'wif', 'u', 'oni']
# 2     ['free', 'entri', '2', 'wkli', 'comp', 'win', ...
# 3     ['u', 'dun', 'say', 'earli', 'hor', 'u', 'c', ...
# 4     ['nah', 'dont', 'think', 'goe', 'usf', 'live',...
# ...                                                 ...
# 5567  ['2nd', 'time', 'tri', '2', 'contact', 'u', 'u...
# 5568         ['ü', 'b', 'go', 'esplanad', 'fr', 'home']
# 5569               ['piti', 'mood', 'soani', 'suggest']
# 5570  ['guy', 'bitch', 'act', 'like', 'id', 'interes...
# 5571                           ['rofl', 'true', 'name']
#
#                                                nltk_pos  \
# 0     [('go', 'VB'), ('jurong', 'JJ'), ('point', 'NN...
# 1     [('ok', 'JJ'), ('lar', 'JJ'), ('joking', 'NN')...
# 2     [('free', 'JJ'), ('entry', 'NN'), ('2', 'CD'),...
# 3     [('u', 'JJ'), ('dun', 'NNS'), ('say', 'VBP'), ...
# 4     [('nah', 'JJ'), ('dont', 'NN'), ('think', 'NN'...
# ...                                                 ...
# 5567  [('2nd', 'CD'), ('time', 'NN'), ('tried', 'VBD...
# 5568  [('ü', 'NN'), ('b', 'NN'), ('going', 'VBG'), (...
# 5569  [('pity', 'NN'), ('mood', 'NN'), ('soany', 'JJ...
# 5570  [('guy', 'NN'), ('bitching', 'VBG'), ('acted',...
# 5571   [('rofl', 'NN'), ('true', 'JJ'), ('name', 'NN')]
#
#                                                nltk_ner  \
# 0     (S\n  go/VB\n  jurong/JJ\n  point/NN\n  crazy/...
# 1         (S ok/JJ lar/JJ joking/NN wif/NN u/JJ oni/NN)
# 2     (S\n  free/JJ\n  entry/NN\n  2/CD\n  wkly/JJ\n...
# 3     (S u/JJ dun/NNS say/VBP early/JJ hor/NN u/JJ c...
# 4     (S\n  nah/JJ\n  dont/NN\n  think/NN\n  goes/VB...
# ...                                                 ...
# 5567  (S\n  2nd/CD\n  time/NN\n  tried/VBD\n  2/CD\n...
# 5568  (S ü/NN b/NN going/VBG esplanade/JJ fr/NN home...
# 5569       (S pity/NN mood/NN soany/JJ suggestions/NNS)
# 5570  (S\n  guy/NN\n  bitching/VBG\n  acted/VBN\n  l...
# 5571                        (S rofl/NN true/JJ name/NN)
#
#                                            spacy_tokens  \
# 0     ['Go', 'until', 'jurong', 'point', ',', 'crazy...
# 1     ['Ok', 'lar', '...', 'Joking', 'wif', 'u', 'on...
# 2     ['Free', 'entry', 'in', '2', 'a', 'wkly', 'com...
# 3     ['U', 'dun', 'say', 'so', 'early', 'hor', '......
# 4     ['Nah', 'I', 'do', "n't", 'think', 'he', 'goes...
# ...                                                 ...
# 5567  ['This', 'is', 'the', '2nd', 'time', 'we', 'ha...
# 5568  ['Will', 'ü', 'b', 'going', 'to', 'esplanade',...
# 5569  ['Pity', ',', '*', 'was', 'in', 'mood', 'for',...
# 5570  ['The', 'guy', 'did', 'some', 'bitching', 'but...
# 5571  ['Rofl', '.', 'Its', 'true', 'to', 'its', 'name']
#
#                                             spacy_stems  \
# 0     ['go', 'until', 'jurong', 'point', ',', 'crazi...
# 1     ['ok', 'lar', '...', 'joke', 'wif', 'u', 'oni'...
# 2     ['free', 'entri', 'in', '2', 'a', 'wkli', 'com...
# 3     ['u', 'dun', 'say', 'so', 'earli', 'hor', '......
# 4     ['nah', 'i', 'do', "n't", 'think', 'he', 'goe'...
# ...                                                 ...
# 5567  ['thi', 'is', 'the', '2nd', 'time', 'we', 'hav...
# 5568  ['will', 'ü', 'b', 'go', 'to', 'esplanad', 'fr...
# 5569  ['piti', ',', '*', 'wa', 'in', 'mood', 'for', ...
# 5570  ['the', 'guy', 'did', 'some', 'bitch', 'but', ...
# 5571    ['rofl', '.', 'it', 'true', 'to', 'it', 'name']
#
#                                            spacy_lemmas  \
# 0     ['go', 'until', 'jurong', 'point', ',', 'crazy...
# 1     ['ok', 'lar', '...', 'joke', 'wif', 'u', 'oni'...
# 2     ['free', 'entry', 'in', '2', 'a', 'wkly', 'com...
# 3     ['u', 'dun', 'say', 'so', 'early', 'hor', '......
# 4     ['Nah', 'I', 'do', 'not', 'think', 'he', 'go',...
# ...                                                 ...
# 5567  ['this', 'be', 'the', '2nd', 'time', 'we', 'ha...
# 5568  ['will', 'ü', 'b', 'go', 'to', 'esplanade', 'f...
# 5569  ['pity', ',', '*', 'be', 'in', 'mood', 'for', ...
# 5570  ['the', 'guy', 'do', 'some', 'bitching', 'but'...
# 5571  ['rofl', '.', 'its', 'true', 'to', 'its', 'name']
#
#                                               spacy_pos  \
# 0     [('Go', 'VERB'), ('until', 'ADP'), ('jurong', ...
# 1     [('Ok', 'INTJ'), ('lar', 'ADJ'), ('...', 'PUNC...
# 2     [('Free', 'ADJ'), ('entry', 'NOUN'), ('in', 'A...
# 3     [('U', 'ADJ'), ('dun', 'NOUN'), ('say', 'VERB'...
# 4     [('Nah', 'PROPN'), ('I', 'PRON'), ('do', 'AUX'...
# ...                                                 ...
# 5567  [('This', 'PRON'), ('is', 'AUX'), ('the', 'DET...
# 5568  [('Will', 'AUX'), ('ü', 'PROPN'), ('b', 'AUX')...
# 5569  [('Pity', 'INTJ'), (',', 'PUNCT'), ('*', 'PUNC...
# 5570  [('The', 'DET'), ('guy', 'NOUN'), ('did', 'VER...
# 5571  [('Rofl', 'ADP'), ('.', 'PUNCT'), ('Its', 'PRO...
#
#                                               spacy_ner
# 0                                  [('Cine', 'PERSON')]
# 1                                                    []
# 2     [('2', 'CARDINAL'), ('FA Cup', 'EVENT'), ('21s...
# 3                                [('U dun', 'PRODUCT')]
# 4                                                    []
# ...                                                 ...
# 5567  [('2nd', 'ORDINAL'), ('2', 'CARDINAL'), ('2', ...
# 5568                                                 []
# 5569                                                 []
# 5570                            [('next week', 'DATE')]
# 5571                                                 []
#
# [5572 rows x 15 columns]
